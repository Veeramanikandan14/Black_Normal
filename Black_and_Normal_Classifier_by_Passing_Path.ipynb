# %%
# !pip install -Uqq fastbook      #install fastbook
import fastbook
from fastbook import *
from fastai.vision.widgets import *
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 719.8/719.8 kB 38.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 53.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 468.7/468.7 kB 45.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 102.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 25.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.5/110.5 kB 16.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 132.9/132.9 kB 18.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.2/212.2 kB 22.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 74.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 17.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 23.7 MB/s eta 0:00:00
# ...

# %%
fastbook.setup_book()       #connects the notebook to gdrive
# Out:
# Mounted at /content/gdrive

# %%
path = Path('/content/gdrive/MyDrive/TaskData1')     #path for the model file in drive
learn = load_learner(path/'Black_Normal_Classifier_Final.pkl')      #loading the model file

# %%
# out_pl = widgets.Output()
def prediction(image):
  img = PILImage.create(image)
  # with out_pl : display(img.show()) 
  display(img.show())
  pred, index, prob = learn.predict(img)
  return int(index)

# %%
fns = get_image_files(path)     #getting the all the image files path
fns[100:]
# Out:
# (#527) [Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/316.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/31111.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/319.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/322.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/322d7a09-23f5-43d0-80ae-ba4ec680cc39.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/329.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/330.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/393ac478-5b53-4adf-a510-32831c84c823.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/000412.jpg'),Path('/content/gdrive/MyDrive/TaskData1/Normal/Normal/000437.jpg')...]

# %%
# upload = widgets.FileUpload()        #for upload button
# upload

# %%
# img_path = upload.data[-1]      #getting image path by upload button data

# %%
img_path = '/content/gdrive/MyDrive/TaskData1/Normal/Normal/329.jpg'      #assign path of image file
out = prediction(img_path)
print(f'Prediction : {out}')      # 0 for black & 1 for Normal
# Out:
# <Axes: >
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# Prediction : 1
